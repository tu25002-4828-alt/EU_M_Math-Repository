# %% [markdown]
# <a href="https://colab.research.google.com/github/tu25002-4828-alt/EU_M_Math-Repository/blob/main/Chap05_Ex10_12%2C15_18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#5-10,11,12
import numpy as np
import numpy.random as random
import scipy as sp
import matplotlib.pyplot as plt
from scipy import interpolate

x = np.linspace(0, 10, num=11, endpoint=True)
y = np.sin(x**2/5.0)

plt.plot(x, y, 'o')
plt.grid(True)

f = interpolate.interp1d(x, y, 'quadratic')

xnew = np.linspace(0, 10, num=30, endpoint=True)

plt.plot(x, y, 'o', xnew, f(xnew),'-')

plt.legend(['data', 'linear', 'quadratic'], loc='best')
plt.grid(True)

f2 = interpolate.interp1d(x, y, 'cubic')

xnew = np.linspace(0, 10, num=30, endpoint=True)

plt.plot(x, y, 'o', xnew, f2(xnew),'--')

plt.legend(['data', 'linear', 'cubic'], loc='best')
plt.grid(True)

# %%
#5-15
from scipy import integrate
import math

def calcPi(x):
  return((x+1)**2)

integrate.quad(calcPi, 0, 2)
# Out:
# (8.666666666666668, 9.621932880084691e-14)

# %%
#5-16
from numpy import cos
integrate.quad(cos, 0, math.pi/1)
# Out:
# (4.9225526349740854e-17, 2.2102239425853306e-14)

# %%
#5-17
from scipy.optimize import fsolve

def f(x):
  y = 5*x - 10
  return y

x = fsolve(f, 0)
print(x)
# Out:
# [2.]

# %%
#5-18
from scipy.optimize import fsolve

def f(x):
  y = x**3 - 2*x**2 - 11*x + 12
  return y

x = fsolve(f, 0)
print(x)
# Out:
# [1.]
