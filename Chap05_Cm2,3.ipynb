# %% [markdown]
# <a href="https://colab.research.google.com/github/tu25002-4828-alt/EU_M_Math-Repository/blob/main/Chap05_Cm2%2C3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#総合問題5-2
import numpy as np
from scipy import integrate

from scipy.optimize import fsolve

def f():
  return integrate.dblquad(lambda y, x:1/(np.sqrt(x+y)*(1+x+y)**2),0,1,lambda x:0,lambda x:1-x)

f()
# Out:
# (0.28539816339745094, 1.5065093091811148e-08)

# %%
#総合問題5-3
import numpy as np
from scipy.optimize import minimize

def f(x):
    return x[0]**2 + 1

x0 = np.array([0.0])

def constraint(x):
    return x[0] + 1

sol = minimize(f, x0, bounds=bounds)

print(sol)
print("最適解 x =", sol.x[0])
print("最小値：", sol.fun)
# Out:
#   message: CONVERGENCE: NORM OF PROJECTED GRADIENT <= PGTOL
#   success: True
#    status: 0
#       fun: 1.0
#         x: [ 0.000e+00]
#       nit: 0
#       jac: [ 0.000e+00]
#      nfev: 2
#      njev: 1
#  hess_inv: <1x1 LbfgsInvHessProduct with dtype=float64>
# 最適解 x = 0.0
# 最小値： 1.0
