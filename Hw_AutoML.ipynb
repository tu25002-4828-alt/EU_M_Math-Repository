# %%
from pycaret.datasets import get_data

data = get_data("iris")
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
from pycaret.classification import *

setup(data=data, target="species", session_id=123)

best = compare_models()

predict_model(best)
# Out:
# <style type="text/css">
# #T_4a6df_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_4a6df">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4a6df_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_4a6df_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4a6df_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4a6df_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_4a6df_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_4a6df_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4a6df_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_4a6df_row1_col1" class="data row1 col1" >species</td>
#     </tr>
#     <tr>
#       <th id="T_4a6df_level0_row2" class="row_heading level0 row2" >2</th>
# ...
